# %%
import pandas as pd
import numpy as np
import pyspark
tips = spark.createDataFrame(tips) # any pandas dataframe

spark = pyspark.sql.SparkSession.builder.getOrCreate()

np.random.seed(13)

pandas_dataframe = pd.DataFrame({
    "n": np.random.randn(20),
    "group": np.random.choice(list("xyz"), 20),
    "abool": np.random.choice([True, False], 20),
})

# %%
pandas_dataframe
# Out:
#            n group  abool
# 0  -0.712391     z  False
# 1   0.753766     x  False
# 2  -0.044503     z  False
# 3   0.451812     y  False
# 4   1.345102     z  False
# 5   0.532338     y  False
# 6   1.350188     z  False
# 7   0.861211     x  False
# 8   1.478686     z   True
# 9  -1.045377     y   True
# 10 -0.788989     x  False
# 11 -1.261606     y  False
# 12  0.562847     y   True
# 13 -0.243326     y   True
# 14  0.913741     y  False
# 15  0.317351     x  False
# 16  0.127303     z  False
# 17  2.150383     y   True
# 18  0.606289     x  False
# 19 -0.026772     x   True

# %% [markdown]
# ### 1. Spark Dataframe Basics

# %%
# i. Use the starter code above to create a pandas dataframe.
pandas_dataframe
# Out:
#            n group  abool
# 0  -0.712391     z  False
# 1   0.753766     x  False
# 2  -0.044503     z  False
# 3   0.451812     y  False
# 4   1.345102     z  False
# 5   0.532338     y  False
# 6   1.350188     z  False
# 7   0.861211     x  False
# 8   1.478686     z   True
# 9  -1.045377     y   True
# 10 -0.788989     x  False
# 11 -1.261606     y  False
# 12  0.562847     y   True
# 13 -0.243326     y   True
# 14  0.913741     y  False
# 15  0.317351     x  False
# 16  0.127303     z  False
# 17  2.150383     y   True
# 18  0.606289     x  False
# 19 -0.026772     x   True

# %%
# ii. Convert the pandas dataframe to a spark dataframe. From this point forward, do all of your work with the 
# spark dataframe, not the pandas dataframe.
df = spark.createDataFrame(pandas_dataframe)
df
# Out:
# DataFrame[n: double, group: string, abool: boolean]

# %%
# iii. Show the first 3 rows of the dataframe.
df.show(3)
# Out:
# +--------------------+-----+-----+
# |                   n|group|abool|
# +--------------------+-----+-----+
# |  -0.712390662050588|    z|false|
# |   0.753766378659703|    x|false|
# |-0.04450307833805...|    z|false|
# +--------------------+-----+-----+
# only showing top 3 rows

# %%
# iv. Show the first 7 rows of the dataframe.
df.show(7)
# Out:
# +--------------------+-----+-----+
# |                   n|group|abool|
# +--------------------+-----+-----+
# |  -0.712390662050588|    z|false|
# |   0.753766378659703|    x|false|
# |-0.04450307833805...|    z|false|
# | 0.45181233874578974|    y|false|
# |  1.3451017084510097|    z|false|
# |  0.5323378882945463|    y|false|
# |  1.3501878997225267|    z|false|
# +--------------------+-----+-----+
# only showing top 7 rows

# %%
# v. View a summary of the data using .describe.
df.describe().show()
# Out:
# +-------+------------------+-----+
# |summary|                 n|group|
# +-------+------------------+-----+
# |  count|                20|   20|
# |   mean|0.3664026449885216| null|
# | stddev|0.8905322898155364| null|
# |    min|-1.261605945319069|    x|
# |    max|2.1503829673811126|    z|
# +-------+------------------+-----+

# %%
# vi. Use .select to create a new dataframe with just the n and abool columns. View the first 5 rows of this dataframe.
df.select('n','abool').show(5)
# Out:
# +--------------------+-----+
# |                   n|abool|
# +--------------------+-----+
# |  -0.712390662050588|false|
# |   0.753766378659703|false|
# |-0.04450307833805...|false|
# | 0.45181233874578974|false|
# |  1.3451017084510097|false|
# +--------------------+-----+
# only showing top 5 rows

# %%
# vii. Use .select to create a new dataframe with the group column and the abool column renamed to a_boolean_value. Show the first 3 rows of this dataframe.
col = df.abool
col
# Out:
# Column<'abool'>

# %%
# viii. Use .select to create a new dataframe with the group column and the n column renamed to a_numeric_value. Show the first 6 rows of this dataframe.
